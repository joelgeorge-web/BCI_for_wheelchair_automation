# %%
import librosa.display
import matplotlib.pyplot as plt
import librosa
import numpy as np
# Load the audio file
file_path = r'C:\Users\Joel\Desktop\PYTHON\BCI_for_wheelchair_automation\jg_rest_eye_left_600.wav'
y, sr = librosa.load(file_path, sr=None)

# Compute the Short-Time Fourier Transform (STFT)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)

# Display the spectrogram
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram of the Audio Signal')
plt.show()
# Out:
# C:\Users\Joel\AppData\Local\Temp\ipykernel_17572\1221408866.py:10: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
